# %%
#
# Created July 17, 2018
# Copyright S.W. Kim
#
import numpy as np
import matplotlib.pyplot

class Perceptron:
    def __init__(self, input_dim, hidden_dim, output_dim, lr=0.01):
        self.w1 =  np.random.normal(0.0, pow(input_dim, -0.5), (input_dim, hidden_dim))
        self.w2 =  np.random.normal(0.0, pow(hidden_dim, -0.5), (hidden_dim, output_dim))
        self.h = np.zeros((1,hidden_dim))
        self.lr = lr
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim        
        self.theta = 0

    def softmax(self, x):
        e_x = np.exp(x - np.max(x))
        return e_x / e_x.sum(axis=0) # only difference
        
    def sigmoid(self, x):
        return 1/(1+np.exp(-x))

    def feedforward(self, x):
        a = x.astype(float)
        b = self.w1.astype(float)
        self.h = self.sigmoid(np.dot(a, b)- self.theta)
        return self.sigmoid(np.dot(self.h, self.w2)- self.theta)

    def feedforward_upto_hidden(self, x):
        return self.sigmoid(np.dot(x, self.w1)- self.theta)

    def bprop_w2(self, g, y): # target, output
        q = (-2)*(g-y)*y*(1-y)

        return np.dot(self.h.reshape(self.hidden_dim,1), q.reshape(1,self.output_dim))

    def bprop_w1(self, g, y, x): # target, output, input
        q1 = (-2)*(g-y)*y*(1-y)
        q2 = np.dot(self.w2, q1)

        return np.dot(x.reshape(self.input_dim, 1), q2*self.h*(1-self.h).reshape(1,self.hidden_dim))
    
    def training(self, input, target):
        x = np.array(input).T
        y = self.feedforward(x)
        g = np.array(target).T
            
        self.w1 = self.w1 - self.lr*self.bprop_w1(g, y, x)
        self.w2 = self.w2 - self.lr*self.bprop_w2(g, y)

# %%
# Training
input_dim = 784
hidden_dim = 300
output_dim = 10
epoch = 10

pct = Perceptron(784,100,10, 0.1)

training_dataset_file = open("mnist_train_200.csv", 'r')
#training_dataset_file = open("mnist_train.csv", 'r')

training_dataset_list = training_dataset_file.readlines()
training_dataset_file.close()
#input_list = list()


for k in range(epoch):
    pct.lr = pct.lr * 0.9  # learning lrate decay
    for i in training_dataset_list:
        all_values = i.split(',')
        inputs = (np.asfarray(all_values[1:])/255.0*0.99)+0.01
#        input_list.append(inputs)
        
        targets = np.zeros(output_dim) + 0.01
        targets[int(all_values[0])] = 0.99
        
        pct.training(inputs, targets)
# Out:
# hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape
# (10,) q
# (100, 10) bprp2
# (100, 1) np.dot(self.h.reshape(self.hidden_dim,1)
# (1, 10) q.reshape(1,self.output_dim)).shape

# %%
# Test
test_dataset_file = open("mnist_test_200.csv", 'r')
#test_dataset_file = open("mnist_test.csv", 'r')

test_dataset_list = test_dataset_file.readlines()
test_dataset_file.close()
#output_list = list()

# %%
all_values = test_dataset_list[0].split(',')
print(all_values[0])
pct.feedforward(np.asfarray(all_values[1:]))
# Out:
# 7
# array([7.72203900e-02, 5.66770184e-04, 1.95352329e-01, 5.49875653e-02,
#        3.50526604e-03, 4.42341957e-02, 7.77150940e-04, 9.65778720e-01,
#        1.01645662e-01, 5.47990124e-01])

# %%
# Test error rate
success = 0
failure = 0

for i in test_dataset_list:
    all_values = i.split(',')
    target = int(all_values[0])
    
    all_values_normalized = (np.asfarray(all_values[1:])/255.0*0.99)+0.01
    prediction_list = pct.feedforward(np.asfarray(all_values_normalized))
    prediction = np.argmax(prediction_list)
    
    if target == prediction:
        success = success + 1
    else:
        failure = failure + 1
        
        print("Prediction fails. (target, predcition) = ", target, prediction)
        print("Prediction = ", prediction_list)

        im_array = np.asfarray(all_values_normalized).reshape((28,28))
        matplotlib.pyplot.imshow(im_array, cmap='Greys', interpolation='None')
        
print("Reconition error rate = ", (failure/(success+failure)))
# Out:
# Prediction fails. (target, predcition) =  4 9
# Prediction =  [0.00783186 0.00786528 0.03482093 0.14828075 0.31235166 0.06952145
#  0.02338384 0.14500877 0.06277108 0.53003462]
# Prediction fails. (target, predcition) =  5 4
# Prediction =  [0.06146826 0.05273695 0.23832093 0.01113919 0.32529966 0.08535429
#  0.09736569 0.01909861 0.0501651  0.01215267]
# Prediction fails. (target, predcition) =  6 2
# Prediction =  [0.07477799 0.01959496 0.30543387 0.03819103 0.085477   0.11120023
#  0.01901712 0.03912183 0.06720712 0.02659703]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.16488033 0.0170868  0.04290557 0.16963692 0.0226234  0.06638929
#  0.01945141 0.07780036 0.08965486 0.04293332]
# Prediction fails. (target, predcition) =  3 2
# Prediction =  [0.0409354  0.01217278 0.21295527 0.2014484  0.03521361 0.05820501
#  0.16533069 0.02270462 0.0396618  0.09025156]
# Prediction fails. (target, predcition) =  6 4
# Prediction =  [0.01055269 0.10029114 0.20910171 0.01280267 0.25713078 0.07476555
#  0.09598705 0.09564915 0.03220542 0.02363745]
# Prediction fails. (target, predcition) =  5 8
# Prediction =  [0.04754334 0.01969574 0.02442053 0.1503826  0.06533443 0.07837411
#  0.13240719 0.01213301 0.17667065 0.0585217 ]
# Prediction fails. (target, predcition) =  7 9
# Prediction =  [0.01929382 0.00733816 0.28729    0.09044389 0.02217905 0.05967035
#  0.011984   0.29862463 0.04400216 0.32346505]
# Prediction fails. (target, predcition) =  7 9
# Prediction =  [0.00994814 0.02019029 0.15278792 0.056559   0.02733566 0.0653875
#  0.01440688 0.34095591 0.06880805 0.40312122]
# Prediction fails. (target, predcition) =  4 9
# Prediction =  [0.00175213 0.04080384 0.07425033 0.05990927 0.47684859 0.04974797
#  0.01631564 0.12891228 0.07728958 0.50824622]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.07109279 0.01034646 0.03173579 0.45874036 0.03275805 0.06430828
#  0.06519466 0.00946464 0.17062056 0.07619871]
# Prediction fails. (target, predcition) =  5 4
# Prediction =  [0.15675216 0.00948474 0.01223665 0.10973776 0.30934192 0.06639268
#  0.0273008  0.05326068 0.04127229 0.07063632]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.06169717 0.01831317 0.05055329 0.22188122 0.04922019 0.06583
#  0.03153791 0.05394204 0.05038853 0.07456491]
# Prediction fails. (target, predcition) =  6 2
# Prediction =  [0.04821399 0.02803933 0.40460847 0.02399955 0.18603142 0.07841923
#  0.04182841 0.05635987 0.04288023 0.01939643]
# Prediction fails. (target, predcition) =  5 7
# Prediction =  [0.0528315  0.06645568 0.03241532 0.01325613 0.11480609 0.22775722
#  0.01552906 0.27530826 0.04552827 0.05169129]
# Prediction fails. (target, predcition) =  8 2
# Prediction =  [0.06910173 0.01043558 0.35812347 0.01327987 0.03993232 0.18208076
#  0.17810114 0.01790638 0.26085147 0.03496956]
# Prediction fails. (target, predcition) =  3 2
# Prediction =  [0.01099977 0.02296969 0.33428573 0.13549894 0.02895853 0.12664029
#  0.06181244 0.02947177 0.16039941 0.18830471]
# Prediction fails. (target, predcition) =  7 4
# Prediction =  [0.01213608 0.01140111 0.1381105  0.09004571 0.29263108 0.11037528
#  0.0170043  0.22810203 0.04247079 0.10892458]
# Prediction fails. (target, predcition) =  4 9
# Prediction =  [0.00682366 0.01754888 0.04597246 0.17200431 0.10024148 0.07688668
#  0.09841594 0.03403837 0.07719685 0.4723755 ]
# Prediction fails. (target, predcition) =  6 2
# Prediction =  [0.03552717 0.06016444 0.23487588 0.02123495 0.11701948 0.15633843
#  0.03154495 0.15202123 0.03451201 0.01241022]
# Prediction fails. (target, predcition) =  9 8
# Prediction =  [0.01223932 0.0595923  0.05633987 0.04114018 0.01567084 0.06948915
#  0.01266059 0.21517146 0.51302982 0.26870316]
# Prediction fails. (target, predcition) =  2 7
# Prediction =  [0.0127144  0.04591773 0.24883655 0.02085413 0.03587961 0.1175236
#  0.02374957 0.41105276 0.03535861 0.14272623]
# Prediction fails. (target, predcition) =  7 9
# Prediction =  [0.02042878 0.00874909 0.03704589 0.06976854 0.14232029 0.06675103
#  0.02540546 0.29281588 0.0188535  0.45105781]
# Prediction fails. (target, predcition) =  7 9
# Prediction =  [0.01563211 0.00837567 0.07099499 0.07659883 0.06002553 0.05916824
#  0.00665055 0.50469046 0.03344746 0.50645865]
# Prediction fails. (target, predcition) =  8 4
# Prediction =  [0.0074823  0.0714043  0.08416558 0.05563301 0.20402889 0.09971114
#  0.03130818 0.03582753 0.20033096 0.09453829]
# Prediction fails. (target, predcition) =  9 4
# Prediction =  [0.01135824 0.04061015 0.04129255 0.02853305 0.26852103 0.11359727
#  0.06417966 0.0741733  0.11768098 0.14297245]
# Prediction fails. (target, predcition) =  7 1
# Prediction =  [0.0038749  0.23024043 0.09173911 0.20084971 0.05826723 0.09165459
#  0.03224261 0.07381963 0.06736135 0.11416892]
# Prediction fails. (target, predcition) =  9 4
# Prediction =  [0.00647516 0.0077891  0.15088851 0.08295475 0.40650359 0.03045263
#  0.03118548 0.12860217 0.05508999 0.30916815]
# Prediction fails. (target, predcition) =  6 2
# Prediction =  [0.0100782  0.0439235  0.23874832 0.01540457 0.14457894 0.07803821
#  0.13209087 0.0470909  0.06049496 0.07201565]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.06087299 0.01058239 0.019931   0.51764336 0.04901801 0.05492664
#  0.00917111 0.05480782 0.12411843 0.14610496]
# Prediction fails. (target, predcition) =  9 4
# Prediction =  [0.01716887 0.02340554 0.14820821 0.15226806 0.25484516 0.06604744
#  0.0347309  0.06754378 0.02262526 0.05947793]
# Prediction fails. (target, predcition) =  7 1
# Prediction =  [0.00200113 0.53149654 0.1087141  0.10904427 0.01298343 0.08612312
#  0.01493269 0.12734081 0.16909129 0.16497037]
# Prediction fails. (target, predcition) =  7 9
# Prediction =  [0.00182663 0.11522024 0.14636748 0.06852417 0.10122447 0.07223601
#  0.04338866 0.14431262 0.09150752 0.18006508]
# Prediction fails. (target, predcition) =  4 9
# Prediction =  [0.00709749 0.01680552 0.03991468 0.00963598 0.18538194 0.04492211
#  0.34427267 0.06366312 0.10054853 0.44165783]
# Prediction fails. (target, predcition) =  4 9
# Prediction =  [0.00209729 0.02058379 0.04674413 0.09278003 0.19420497 0.06165009
#  0.10324553 0.05489592 0.1233175  0.60272225]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.08107261 0.00857424 0.05097479 0.78606723 0.05312281 0.04327939
#  0.02393271 0.01002071 0.09126673 0.05272602]
# Prediction fails. (target, predcition) =  4 6
# Prediction =  [0.01871875 0.01925937 0.04224956 0.00591062 0.28605076 0.066451
#  0.33101083 0.09144914 0.05477075 0.10259876]
# Prediction fails. (target, predcition) =  7 9
# Prediction =  [0.00460847 0.03486986 0.09276684 0.22541973 0.0452863  0.06480073
#  0.01688545 0.16275733 0.04171107 0.31582204]
# Prediction fails. (target, predcition) =  7 9
# Prediction =  [0.00913738 0.00998172 0.00978145 0.08926158 0.24054305 0.05778115
#  0.01863024 0.40764931 0.0648352  0.58047476]
# Prediction fails. (target, predcition) =  0 2
# Prediction =  [0.43774653 0.00395085 0.45026526 0.12565663 0.0148063  0.09742422
#  0.01006004 0.13394042 0.02128645 0.0105156 ]
# Prediction fails. (target, predcition) =  5 0
# Prediction =  [0.16516819 0.02704723 0.01549318 0.04890428 0.06503164 0.08779525
#  0.01407033 0.06677789 0.15616932 0.10169395]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.08202902 0.01790404 0.02028412 0.28505889 0.03177137 0.05434659
#  0.02891943 0.01762253 0.26905343 0.10815169]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.11182288 0.00715692 0.13242705 0.32461177 0.00862604 0.04430812
#  0.13870575 0.00675502 0.13690075 0.03491807]
# Prediction fails. (target, predcition) =  7 2
# Prediction =  [0.01166716 0.00533077 0.50077731 0.03186972 0.07424116 0.04822054
#  0.03184932 0.1862535  0.08962543 0.18251333]
# Prediction fails. (target, predcition) =  7 9
# Prediction =  [0.00526698 0.01631963 0.17337488 0.01129335 0.19328068 0.05750009
#  0.04342248 0.20493497 0.06934469 0.41080021]
# Prediction fails. (target, predcition) =  2 4
# Prediction =  [0.01127767 0.06675111 0.09047871 0.08633119 0.1409946  0.06167357
#  0.06341514 0.03622097 0.09046068 0.11519045]
# Prediction fails. (target, predcition) =  9 4
# Prediction =  [0.00916185 0.00906871 0.08331851 0.11564222 0.2973699  0.03458493
#  0.07679343 0.02652138 0.06179238 0.26335804]
# Prediction fails. (target, predcition) =  9 2
# Prediction =  [0.04910594 0.00826432 0.24290278 0.1908027  0.13194326 0.0409582
#  0.00985761 0.10300497 0.03914922 0.10116045]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.08873568 0.01188037 0.0733123  0.36965552 0.01364162 0.06387967
#  0.01862036 0.02467398 0.14981338 0.10978678]
# Prediction fails. (target, predcition) =  5 8
# Prediction =  [0.06382426 0.02276409 0.01361151 0.07542404 0.11805832 0.08145708
#  0.06717168 0.02806179 0.16200948 0.1334698 ]
# Prediction fails. (target, predcition) =  6 4
# Prediction =  [0.01690892 0.01298189 0.17177138 0.01030406 0.34500689 0.09192938
#  0.32430964 0.05895676 0.01466271 0.05001713]
# Prediction fails. (target, predcition) =  3 2
# Prediction =  [0.09856134 0.02392956 0.20289582 0.16643055 0.0054516  0.10406411
#  0.03654503 0.09149454 0.03084378 0.01872192]
# Prediction fails. (target, predcition) =  4 9
# Prediction =  [0.00215357 0.02028963 0.07121655 0.03979426 0.44420409 0.07624883
#  0.06107133 0.11795103 0.09212199 0.47130114]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.20183647 0.00734508 0.03406372 0.57684766 0.01820885 0.07217083
#  0.00875226 0.0163771  0.26451806 0.04882715]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.14367471 0.0078463  0.08861103 0.30588782 0.01394424 0.05126563
#  0.08561425 0.01559334 0.10144697 0.03483794]
# Prediction fails. (target, predcition) =  4 9
# Prediction =  [0.00558305 0.008663   0.04423521 0.17924275 0.29647786 0.0479237
#  0.04488781 0.05934706 0.04154831 0.63461837]
# Prediction fails. (target, predcition) =  2 3
# Prediction =  [0.16727998 0.01627122 0.44723058 0.46663629 0.01255406 0.11499767
#  0.00768629 0.00911996 0.11276151 0.00683077]
# Prediction fails. (target, predcition) =  7 1
# Prediction =  [0.00838912 0.20390265 0.07655113 0.10660599 0.03353178 0.10191758
#  0.01852969 0.14661401 0.08334398 0.09776473]
# Prediction fails. (target, predcition) =  5 8
# Prediction =  [0.05908653 0.04785108 0.02576607 0.08138344 0.02901529 0.10107359
#  0.04740367 0.03552088 0.14487599 0.11813557]
# Prediction fails. (target, predcition) =  5 3
# Prediction =  [0.08835479 0.009953   0.07967001 0.62979608 0.01969635 0.05186356
#  0.02506177 0.01074484 0.16553011 0.10029663]
# Prediction fails. (target, predcition) =  9 3
# Prediction =  [0.00397339 0.02979435 0.07194224 0.46648053 0.19967364 0.06530002
#  0.03558309 0.06791563 0.03370641 0.2057927 ]
# Prediction fails. (target, predcition) =  4 9
# Prediction =  [0.00588561 0.00584697 0.03927666 0.0695009  0.30517774 0.06768053
#  0.06705238 0.07731753 0.0985349  0.61035676]
# Reconition error rate =  0.31
